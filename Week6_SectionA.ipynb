# %% [markdown]
# <a href="https://colab.research.google.com/github/jamarathe2025/cvllm/blob/main/Week6_SectionA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Section A: LLM Foundations & Hugging Face
# **Hugging Face Setup & Text Generation**
# 1. Install Hugging Face transformers.
# 2. Load a small LLM (e.g., distilgpt2).
# 3. Generate three different continuations for the prompt: “AI is transforming industries by …”.
#
# Deliverable: Notebook cell with outputs.

# %%
pip install transformers torch
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (5.0.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.10.0+cpu)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.24.3)
# Requirement already satisfied: huggingface-hub<2.0,>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (1.4.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer-slim in /usr/local/lib/python3.12/dist-packages (from transformers) (0.24.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (1.3.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (0.28.1)
# Requirement already satisfied: shellingham in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (1.5.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: typer>=0.24.0 in /usr/local/lib/python3.12/dist-packages (from typer-slim->transformers) (0.24.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (4.12.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (0.16.0)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer>=0.24.0->typer-slim->transformers) (8.3.1)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.24.0->typer-slim->transformers) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer>=0.24.0->typer-slim->transformers) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer>=0.24.0->typer-slim->transformers) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer>=0.24.0->typer-slim->transformers) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer>=0.24.0->typer-slim->transformers) (0.1.2)

# %% [markdown]
# Setup 1

# %%
from transformers import pipeline

# %%
generator = pipeline("text-generation", model="distilbert/distilgpt2")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/762 [00:00<?, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# model.safetensors:   0%|          | 0.00/353M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/76 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: distilbert/distilgpt2
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# transformer.h.{0, 1, 2, 3, 4, 5}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]

# %%
prompt = "AI is transforming industries by"

# %%
results = generator(
    prompt,
    max_new_tokens=30,
    num_return_sequences=3,
    do_sample=True,
    temperature=0.5
)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=30) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)

# %%
for i, res in enumerate(results):
    print(f"Response Continuation {i+1}: {res['generated_text']}\n")
# Out:
# Response Continuation 1: AI is transforming industries by creating jobs.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Response Continuation 2: AI is transforming industries by offering the opportunity to develop a new, innovative, and sustainable business model for the future.
#
#
#
#
#
#
#
#
#
#
#
#
#
# Response Continuation 3: AI is transforming industries by providing more efficient and reliable fuel.”

# %% [markdown]
# Displaying output HTML table

# %%
gen_rows = ""
for i, res in enumerate(results):
    text = res['generated_text']
    gen_rows += f"<tr><td style='padding:8px;'><b>Continuation {i+1}</b></td><td style='padding:8px;'>{text}</td></tr>"

gen_html = f"""
<h3>1. LLM Generation Results (DistilGPT2)</h3>
<p><b>Prompt:</b> {prompt}</p>
<table border="1" style="width:100%; border-collapse:collapse; font-family:sans-serif;">
    <tr style="background-color: #e6f3ff;">
        <th style="padding:10px; width:20%;">ID</th>
        <th style="padding:10px;">Generated Text</th>
    </tr>
    {gen_rows}
</table>
<br><hr>
"""
display(HTML(gen_html))
# Out:
# <h3>1. LLM Generation Results (DistilGPT2)</h3>
# <p><b>Prompt:</b> AI is transforming industries by</p>
# <table border="1" style="width:100%; border-collapse:collapse; font-family:sans-serif;">
#     <tr style="background-color: #e6f3ff;">
#         <th style="padding:10px; width:20%;">ID</th>
#         <th style="padding:10px;">Generated Text</th>
#     </tr>
#     <tr><td style='padding:8px;'><b>Continuation 1</b></td><td style='padding:8px;'>AI is transforming industries by creating jobs.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# </td></tr><tr><td style='padding:8px;'><b>Continuation 2</b></td><td style='padding:8px;'>AI is transforming industries by offering the opportunity to develop a new, innovative, and sustainable business model for the future.
#
#
#
#
#
#
#
#
#
#
#
# </td></tr><tr><td style='padding:8px;'><b>Continuation 3</b></td><td style='padding:8px;'>AI is transforming industries by providing more efficient and reliable fuel.”</td></tr>
# </table>
# <br><hr>

# %% [markdown]
# # **Section A: LLM Foundations & Hugging Face**
# **Tokenization Demo**
# 1. Take the sentence: “LLMs are powerful tools for natural language understanding.”
# 2. Tokenise it using a Hugging Face tokeniser.
# 3. Display the resulting tokens, token IDs, and sequence length.

# %%
from transformers import AutoTokenizer

# %% [markdown]
# Load the tokenizer for distilgpt2

# %%
tokenizer = AutoTokenizer.from_pretrained("distilbert/distilgpt2")

# %% [markdown]
# Define the sentence

# %%
sentence = "LLMs are powerful tools for natural language understanding."

# %% [markdown]
# Tokenize the sentence and Get individual tokens

# %%
inputs = tokenizer(sentence)
tokens = tokenizer.tokenize(sentence)

# %% [markdown]
# Extract IDs and Sequence Length

# %%
token_ids = inputs['input_ids']
sequence_length = len(token_ids)

# %% [markdown]
# Final result

# %%
print(f"Sentence: {sentence}")
print(f"-"*30)
print(f"Tokens: {tokens}")
print(f"Token IDs: {token_ids}")
print(f"Sequence Length: {sequence_length} tokens")
# Out:
# Sentence: LLMs are powerful tools for natural language understanding.
# ------------------------------
# Tokens: ['LL', 'Ms', 'Ġare', 'Ġpowerful', 'Ġtools', 'Ġfor', 'Ġnatural', 'Ġlanguage', 'Ġunderstanding', '.']
# Token IDs: [3069, 10128, 389, 3665, 4899, 329, 3288, 3303, 4547, 13]
# Sequence Length: 10 tokens

# %% [markdown]
# Making result more presentable using HTML table

# %%
from IPython.display import HTML, display

# --- Replace your '# Display Results' section with this ---

# 1. Prepare table rows
table_rows = ""
for i, (token, tid) in enumerate(zip(tokens, token_ids)):
    # GPT tokenizers use 'Ġ' to represent a space; we replace it for readability
    readable_token = token.replace('Ġ', ' ')
    table_rows += f"<tr><td>{i}</td><td>{readable_token}</td><td>{tid}</td></tr>"

# 2. Define the HTML structure
html_table = f"""
<h3>Tokenization Analysis</h3>
<p><b>Sentence:</b> {sentence}</p>
<p><b>Total Sequence Length:</b> {len(token_ids)}</p>
<table border="1" style="width:50%; border-collapse:collapse; text-align:left;">
    <tr style="background-color: #f2f2f2;">
        <th>Index</th>
        <th>Token</th>
        <th>Token ID</th>
    </tr>
    {table_rows}
</table>
"""

# 3. Render the table in Colab
display(HTML(html_table))
# Out:
# <h3>Tokenization Analysis</h3>
# <p><b>Sentence:</b> LLMs are powerful tools for natural language understanding.</p>
# <p><b>Total Sequence Length:</b> 10</p>
# <table border="1" style="width:50%; border-collapse:collapse; text-align:left;">
#     <tr style="background-color: #f2f2f2;">
#         <th>Index</th>
#         <th>Token</th>
#         <th>Token ID</th>
#     </tr>
#     <tr><td>0</td><td>LL</td><td>3069</td></tr><tr><td>1</td><td>Ms</td><td>10128</td></tr><tr><td>2</td><td> are</td><td>389</td></tr><tr><td>3</td><td> powerful</td><td>3665</td></tr><tr><td>4</td><td> tools</td><td>4899</td></tr><tr><td>5</td><td> for</td><td>329</td></tr><tr><td>6</td><td> natural</td><td>3288</td></tr><tr><td>7</td><td> language</td><td>3303</td></tr><tr><td>8</td><td> understanding</td><td>4547</td></tr><tr><td>9</td><td>.</td><td>13</td></tr>
# </table>
